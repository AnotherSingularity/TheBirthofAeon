# %%
import requests

ngrok_url = "https://c6a4-34-172-106-11.ngrok-free.app"  # Your actual node URL

node_data = {"node_address": "https://c6a4-34-172-106-11.ngrok-free.app"}  # Registering itself for now

response = requests.post(f"{ngrok_url}/register_node", json=node_data)
print("Register Node Response:", response.json())
# Out:
# Register Node Response: {'message': 'Node registered', 'peers': ['https://c6a4-34-172-106-11.ngrok-free.app']}

# %%
import requests

ngrok_url = "https://c6a4-34-172-106-11.ngrok-free.app"  # Your actual node URL

sync_response = requests.get(f"{ngrok_url}/sync_chain")
print("Sync Chain Response:", sync_response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/requests/models.py in json(self, **kwargs)
#     973         try:
# --> 974             return complexjson.loads(self.text, **kwargs)
#     975         except JSONDecodeError as e:
#
# /usr/lib/python3.11/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.11/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.11/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# ...

# %%
import requests

ngrok_url = "https://5440-34-172-106-11.ngrok-free.app"  # Updated URL

data = {"data": "PoC + Rewards", "miner": "Node_1"}

response = requests.post(f"{ngrok_url}/new_transaction", json=data)
print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 201
# Response: {'block': {'data': 'PoC + Rewards', 'difficulty': 2, 'hash': 'f193e7a898300edb86d663ad138fecb86e174ad2fc115bdc84ae6f3fa6c01656', 'index': 1, 'miner': 'Node_1', 'previous_hash': '5197c4b30253c17c4596cc1a6621480d421a955d89a4d383cc220784aef6edfd', 'proof': 286, 'reward': 250, 'timestamp': 1740611428.788592}, 'message': 'New block added'}

# %%
import requests

ngrok_url = "https://891f-34-172-106-11.ngrok-free.app"
response = requests.get(f"{ngrok_url}/chain")

print("Status Code:", response.status_code)
print("Response:", response.text)  # Print raw response to debug
# Out:
# Status Code: 200
# Response: {"chain":[{"data":"Genesis Block","difficulty":2,"hash":"02436453ebb4b0254c5585aad13c1aab2488d01ebc33eb092c369467b2f6c28e","index":0,"miner":"Network","previous_hash":"0","proof":0,"reward":50,"timestamp":1740612689.709319,"total_supply":1000000000,"treasury_locked":{"ecosystem":150000000,"governance":100000000,"liquidity":100000000}},{"data":"PoC Test Transaction","difficulty":2,"hash":"0abb0d4542434dcfa681acabb3b114b76d712effdcfb47786e35f1a6a2b570c9","index":1,"miner":"Node_1","previous_hash":"02436453ebb4b0254c5585aad13c1aab2488d01ebc33eb092c369467b2f6c28e","proof":286,"reward":250,"timestamp":1740612767.7291403,"total_supply":999999750,"treasury_locked":{"ecosystem":150000000,"governance":100000000,"liquidity":100000000}}],"length":2,"total_supply":999999750,"treasury_locked":{"ecosystem":150000000,"governance":100000000,"liquidity":100000000}}

# %%
import requests

ngrok_url = "https://891f-34-172-106-11.ngrok-free.app"  # Your main node URL
node_data = {"node_address": "https://another-node.ngrok-free.app"}  # Replace with an actual node

response = requests.post(f"{ngrok_url}/register_node", json=node_data)
print("Register Node Response:", response.json())

sync_response = requests.get(f"{ngrok_url}/sync_chain")
print("Sync Chain Response:", sync_response.json())
# Out:
# Register Node Response: {'message': 'Node registered', 'peers': ['https://another-node.ngrok-free.app']}
# Sync Chain Response: {'message': 'Chain is already up-to-date'}

# %%
import requests

ngrok_url = "https://891f-34-172-106-11.ngrok-free.app"

proposal_data = {"category": "ecosystem", "amount": 5000000}
response = requests.post(f"{ngrok_url}/propose_funding", json=proposal_data)

print("Proposal Response:", response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/requests/models.py in json(self, **kwargs)
#     973         try:
# --> 974             return complexjson.loads(self.text, **kwargs)
#     975         except JSONDecodeError as e:
#
# /usr/lib/python3.11/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.11/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.11/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# ...
