# %%
import requests

ngrok_url = "https://1a5a-34-172-106-11.ngrok-free.app"
response = requests.get(f"{ngrok_url}/chain")
print(response.json())
# Out:
# {'chain': [{'data': 'Genesis Block', 'hash': 'd79fb45ba7ab1bfe10e9dbda3044560ac27823a1ab8fecc747807873a8effcd5', 'index': 0, 'previous_hash': '0', 'proof': 0, 'timestamp': 1740608128.798185}], 'length': 1}

# %%
import requests

ngrok_url = "https://1a5a-34-172-106-11.ngrok-free.app"

data = {
    "data": "First AI Transaction",
    "proof": 67890
}

response = requests.post(f"{ngrok_url}/new_transaction", json=data)
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/requests/models.py in json(self, **kwargs)
#     973         try:
# --> 974             return complexjson.loads(self.text, **kwargs)
#     975         except JSONDecodeError as e:
#
# /usr/lib/python3.11/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.11/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.11/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# ...

# %%
import requests

ngrok_url = "https://5cf7-34-172-106-11.ngrok-free.app"  # Update with new ngrok URL

response = requests.get(f"{ngrok_url}/chain")
print("Status Code:", response.status_code)
print("Response:", response.text)
# Out:
# Status Code: 200
# Response: {"chain":[{"data":"Genesis Block","hash":"ac9d78712e39bdfd16f1ea22c72c976567fa5db1f80fe4e041b5515694c370a8","index":0,"previous_hash":"0","proof":0,"timestamp":1740609392.0184987}],"length":1}

# %%
import requests

ngrok_url = "https://5cf7-34-172-106-11.ngrok-free.app"  # Keep this updated

data = {
    "data": "First AI Transaction",
    "proof": 67890
}

response = requests.post(f"{ngrok_url}/new_transaction", json=data)
print("Status Code:", response.status_code)
print("Response:", response.text)
# Out:
# Status Code: 201
# Response: {"block":{"data":"First AI Transaction","hash":"de4597c897c64867ecf1391f8dc478217d7ca857d3cca805abb9069399b75bd0","index":1,"previous_hash":"ac9d78712e39bdfd16f1ea22c72c976567fa5db1f80fe4e041b5515694c370a8","proof":67890,"timestamp":1740609568.0184166},"message":"New block added"}

# %%
import requests

ngrok_url = "https://0617-34-172-106-11.ngrok-free.app"  # Using your latest ngrok URL

data = {"data": "PoC Transaction"}

response = requests.post(f"{ngrok_url}/new_transaction", json=data)
print("Status Code:", response.status_code)
print("Response:", response.text)
# Out:
# Status Code: 201
# Response: {"block":{"data":"PoC Transaction","hash":"8f6403ba19f64a30442953ce2493b11fdbdf0f896222c39540d66b3e07afece0","index":1,"previous_hash":"a82f4edd0918d6dc1a02056763c0c77142c7381235450bb61dfea4604ba1cabb","proof":286,"timestamp":1740610059.090609},"message":"New block added"}

# %%
import requests

ngrok_url = "https://c299-34-172-106-11.ngrok-free.app"  # Keep this updated

data = {"data": "PoC + Dynamic Scaling"}

response = requests.post(f"{ngrok_url}/new_transaction", json=data)
print("Status Code:", response.status_code)
print("Response:", response.text)
# Out:
# Status Code: 201
# Response: {"block":{"data":"PoC + Dynamic Scaling","difficulty":2,"hash":"9872372758fb65bbf51845795c6eb52333fdce995061d758bb6438df7fc70193","index":1,"previous_hash":"7b5546e88072aab56a068571473a8ca826f4b81941417455ed6e3e31c6ea37f6","proof":286,"timestamp":1740610382.9280517},"message":"New block added"}

# %%
import requests

ngrok_url = "https://c6a4-34-172-106-11.ngrok-free.app"  # Updated URL

data = {"data": "PoC + Rewards", "miner": "Node_1"}

response = requests.post(f"{ngrok_url}/new_transaction", json=data)
print("Status Code:", response.status_code)
print("Response:", response.text)
# Out:
# Status Code: 201
# Response: {"block":{"data":"PoC + Rewards","difficulty":2,"hash":"64f626657903e9e1cf7afc0b34dd6e209fe44c86e0d1e88cb0585d9d7ef41fe4","index":1,"miner":"Node_1","previous_hash":"cf8b10da11e0e6e2b97fa84214e68306418804cea84ee066b3d5f2b40c935797","proof":286,"reward":250,"timestamp":1740610579.9864795},"message":"New block added"}

# %%
import requests

ngrok_url = "https://5440-34-172-106-11.ngrok-free.app"  # Your main node

node_data = {"node_address": "https://another-node.ngrok-free.app"}  # Replace with your second node URL
response = requests.post(f"{ngrok_url}/register_node", json=node_data)
print("Register Node Response:", response.json())
# Out:
# Register Node Response: {'message': 'Node registered', 'peers': ['https://another-node.ngrok-free.app']}

# %%
sync_response = requests.get(f"{ngrok_url}/sync_chain")
print("Sync Chain Response:", sync_response.json())
# Out:
# Sync Chain Response: {'message': 'Chain is already up-to-date'}

# %%
import requests

ngrok_url = "https://891f-34-172-106-11.ngrok-free.app"  # Use your latest URL

data = {"data": "PoC Test Transaction", "miner": "Node_1"}
response = requests.post(f"{ngrok_url}/new_transaction", json=data)
print("Status Code:", response.status_code)
print("Response:", response.json())
# Out:
# Status Code: 201
# Response: {'block': {'data': 'PoC Test Transaction', 'difficulty': 2, 'hash': '0abb0d4542434dcfa681acabb3b114b76d712effdcfb47786e35f1a6a2b570c9', 'index': 1, 'miner': 'Node_1', 'previous_hash': '02436453ebb4b0254c5585aad13c1aab2488d01ebc33eb092c369467b2f6c28e', 'proof': 286, 'reward': 250, 'timestamp': 1740612767.7291403, 'total_supply': 999999750, 'treasury_locked': {'ecosystem': 150000000, 'governance': 100000000, 'liquidity': 100000000}}, 'message': 'New block added'}

# %%
response = requests.get(f"{ngrok_url}/chain")
print("Total Supply:", response.json()["total_supply"])
print("Treasury Locked Funds:", response.json()["treasury_locked"])
# Out:
# Total Supply: 999999750
# Treasury Locked Funds: {'ecosystem': 150000000, 'governance': 100000000, 'liquidity': 100000000}
